# %% [markdown]
# ## Question 3 - Ace the AI!
#
# ### Logistics:
# - #### Marks - 25
# - #### Estimated Time - ~ 35 minutes
#
# ### Q. Formulate a question from what all we have learnt from the class so that Deepseek cannot answer it correctly. Provide the question, its correct answer and Deepseek's answer as deliverables.
# - #### Everything must be clearly documented in separate sections.
# - #### It can be a tricky dataset, a numerical, some coding request etc.
# - #### Or some optimization question where you trump the AI.
# - #### You have to genuinely prompt the AI for better/improved solution atleast 3 times.
# - #### Upload all the files that you generate in the process
#
# ### Evaluation
# - #### We will run your query on AI and evaluate. If after 3 prompts we are not able to beat your solution, you win
# - #### Provide us with the full prompt that we should give to AI to properly solve the problem (in text format)
# - #### Creative answers required!
# - #### Partial grading will be done
