# %% [markdown]
# ## Question 3 - Chinese MNIST
#
# ### Logistics:
# - #### Marks - 5 + 15
# - #### Estimated Time - ~ 35 minutes
# - #### You will find the train/test files in the folder named ```./data/q1```
#
# ### What is same as last time?
# - #### The dataset - The train and test set
# - #### The task - Predict the mean salary of different cities
# - #### The Loss function - Root Mean Percentage Square Error (RMPSE)
#
# ### What is different from last time?
# - #### The constraints - You can only use 2 models to make the final prediction
# - #### Part A - Train a Linear Regression Model to get the final predictions for the test set
# - #### Part B - Train a 2 layered Neural Network Model (```Inp - 32 - 32 - Out``` as total network architecture) to get the final predictions for the test set
#
# ### Deliverables
# - #### Two files containing the salary predictions on the test set
# - #### Name the files in the format - **\<ID-NO\>-LR.csv** for Linear regression and **\<ID-NO\>-NN.csv** for Neural Networks
# - #### You have to upload the above mentioned csv files on quanta after you are done.
#
# ### Evaluation
# - #### Like last time, you will be evaluated based on the performance of your model on the test set.
#
# ### Take care
# - #### Write **clean** code. It should compile. **Code that does not compile will not be evaluated**
# -
# - #### Make sure that you only use the above mentioned models as the final models to make predictions. Any breakage of rules will lead to straight disqualification
