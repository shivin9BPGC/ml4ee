# %% [markdown]
# ## Question - Marks Prediction
#
# ### Logistics:
# - #### Marks - 79
# - #### Estimated Time - ~ 120 minutes
#
# ### Take care
# - #### Write **clean** code. It should compile. **Code that does not compile will not be evaluated**
# - #### Upload all the required files
# - #### Make sure that you only use the above mentioned models as the final models to make predictions. Any breakage of rules will lead to straight disqualification
